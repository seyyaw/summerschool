# %% [markdown]
# <a href="https://colab.research.google.com/github/seyyaw/summerschool/blob/main/Data_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <style>
# table {display: block;}
# td {
#   font-size: 18px
# }
# .rendered_html { font-size: 28px; }
# *{ line-height: 200%; }
# </style>
# Out:
# <style>
# table {display: block;}
# td {
#   font-size: 18px
# }
# .rendered_html { font-size: 28px; }
# *{ line-height: 200%; }
# </style>

# %% [markdown]
# # Summer School for Women in AI and Data Sceince
# ---
# ---
# # <span style="color:blue">Natural Language Processing</span>
#  ---
# ## -  <span style="color:red">Seid Muhie Yimam  - UHH, HCDS</span>
# ---
# ---

# %% [markdown]
# # Content
# - Data Sources
# - Data Collection And Sampling
# - Data Annotation
# - Data Sharing

# %% [markdown]
# ## Determining the Need for Data Collection
#
# - Always utilize existing data before gathering new data.
#
# Explore Available Data Sources:
# 1. Academic Research:
#    - Review relevant academic papers to see if the datasets are published or referenced.
#
# 2. Online Repositories:
#    - Explore platforms like GitHub and HuggingFace for publicly available datasets.
#
# 3. Open Data Organizations:
#    - Check with organizations that provide open access to datasets.
#
# 4. Institutional Resources:
#    - Investigate whether your own company or institute has the data you need or if partnerships for data sharing exist.

# %% [markdown]
# # Data Sources
# - Data sources are application specific
# ## Collection approach
# - Know your data need, define specification (text, speech, image, multimodal)
# - Identify the source (Website, news, API access,...)
# - Identify the tool
# - Get annotators

# %% [markdown]
# ## Website Data - scrapping
# - Selenium
# - Beautiful Soup
# - Tesseract OCR for PDF

# %% [markdown]
# - [Papers With Code](https://paperswithcode.com/)
# - [Kaggle](https://wwww.kaggle.com/)
# - [Common Crawl](https://commoncrawl.org/)
# - ...

# %% [markdown]
# ## Licensing and Ethics in Data Collection and Annotation
#
# 1. Legal Compliance:
#    -  Adhere to data licensing laws and copyright standards.
# 2. Privacy Protection:
#    - Follow privacy regulations like GDPR and ensure proper consent.
# 3. Transparency:
#    - Clearly communicate data use, collection methods, and purposes.
# 4. Ethical Annotations:
#    - Ensure annotated data is used responsibly and promotes inclusivity.

# %% [markdown]
# # Sampling Data for Annotation
#
# 1. Random Sampling: Ensure unbiased data selection.
#
# 2. Stratified Sampling: Represent all categories proportionally.
#
# 3. Convenience Sampling: Use easily accessible data if applicable.
#
# 4. Purposeful Sampling: Target specific data traits for detailed insights.

# %% [markdown]
# # Know the types of data
# 1. Machine Learning Prediction:
#    - Use numeric, continuous, and time series data for outcomes like prices or trends.
#
# 2. Machine Learning Classification:
#    - Employ categorical data, text, and images for labeled classification tasks.
#
# 3. Large Language Models:
#    - Collect diverse, extensive text corpora and annotated data for comprehensive language understanding.
#
# 4. Medical Domain:
#    - Utilize structured clinical data and imaging for diagnostics and predictive analytics.
#
# 5. Legal Domain:
#    - Incorporate text from legal documents and anonymized case histories for NLP and trend analysis.

# %% [markdown]
# #  Data Annotation
# - Annotation is the process of `labeling data` to indicate the information it represents. This `enriches raw data` (like `texts`, `images`, or `audio`) with relevant context so that machine learning models can learn from it and make `predictions` or classifications `based on these labeled inputs`.

# %% [markdown]
#  ## Introduction to Data Annotation
# - Importance of Data Annotation in ML
#   - Data annotation crucial for optimal ML model performance
#   - Takes up 80% of ML prep time: collection, cleaning, labeling
#   - Proper annotation strategies enhance machine learning pipelines
#   - Essential for supervised and unsupervised learning models

# %% [markdown]
# ## Components of Data Annotation
# - Key Elements for an Effective Annotation Strategy
#   - Data Collection
#     - Define ML project goals and data requirements
#     - Ensure data variety to avoid biases and enhance model accuracy
#     - Opt for appropriate data storage and formatting
#   - Human Involvement
#     - Human expertise vital despite automation
#     - Team: engineers, scientists, annotators, managers
#     - Importance of subject-matter experts for complex data

# %% [markdown]
# ## Annotation Processes and Techniques
# - Optimizing the Data Labeling Process
#   - Data Labeling Phases
#     - Initial training: Structured annotation according to guidelines
#     - Model fine-tuning: Continuous annotation for accuracy improvement
#     - Use of Human-in-the-loop (HITL) and active learning for automation synergy
#   - Process Scalability
#     - Iterative annotation approach with ongoing adjustments
#     - Balancing manual and automated annotation efforts

# %% [markdown]
# ## Technological Support and Strategies
# - Leveraging Technology and Strategic Planning in Annotation
#   - Tool Selection
#     - Choose annotation tools that align with data types and ML needs
#     - Automation features to handle large datasets efficiently
#   - Strategic Annotation Planning
#     - Establish clear objectives and guidelines for the annotation team
#     - Document and secure annotation workflows to protect data integrity
#     - Emphasize quality assurance and regular progress evaluations

# %% [markdown]
# # The annotation life cycle
# ![](https://www.oreilly.com/api/v2/epubs/9781449332693/files/figs/web/nlml_0110.png)

# %% [markdown]
# ![](https://labelyourdata.com/img/article-illustrations/active_learning_explainedi.jpg)

# %% [markdown]
# # Annotation tools
# ![](https://i.ytimg.com/vi/rBnKwDqfutE/hqdefault.jpg)

# %% [markdown]
# # Text Annotation:
#    - `Prodigy`: Efficient, scriptable tool integrating machine learning for faster annotation cycles.
#    - `Brat`: Web-based tool, useful for detailed annotation of entities, relationships, and events.
#    - `WebAnno`: Versatile web-based annotation for various textual interpretations, supports collaborative projects.
#    - `Potato`: Known as the Portable Text Annotation Tool, designed for ease of use, making it accessible for everyone.

# %% [markdown]
# # Speech Annotation:
#    - `Praat`: Powerful tool for speech analysis and annotating audio files.
#    - ![](https://colangpraat.files.wordpress.com/2014/06/praat-what-do-i-need-to-know-003.jpg)
#    - `ELAN`: Specializes in detailed, layered annotations for audio and video.

# %% [markdown]
# # mage Annotation:
#    - `LabelImg`: User-friendly tool for bounding box annotations on images.
#    - `CVAT` (Computer Vision Annotation Tool): Feature-rich, web-based tool for object tracking, task distribution, and segmentation.
#    ![](https://viso.ai/wp-content/uploads/2021/10/computer-vision-annotation-tool-cvat-preview.jpg)

# %% [markdown]
# ## Inter-Annotator Agreement (IAA)
# - Pair-wise `Cohen kappa` and group `Fleiss’ kappa` (𝜅) coefficients for categorical annotations
# - ![](https://www.researchgate.net/publication/347970159/figure/tbl1/AS:975092074946560@1609491475065/Interpretation-of-Cohens-kappa.png)

# %% [markdown]
# # Data Sharing
# - Data Anonymization:
#    - Before sharing, sensitive information must be anonymized to protect privacy and confidentiality.
# - Documentation and Metadata:
#    - Provide comprehensive documentation and metadata, which includes details about data collection, structure, intended use, and any preprocessing steps taken.

# %% [markdown]
# - Accessibility:
#    - Make the datasets easily accessible to encourage widespread use and adoption. This involves using common file formats and well-organized data structures
# - Version Control:
#    - Maintain versions of the dataset to manage updates or corrections effectively. This helps users stay updated with the most accurate data version.
# - Quality Assurance:
#    - Ensure the dataset is of high quality, with minimal errors or inconsistencies, as this enhances its utility for machine learning or statistical analysis.

# %% [markdown]
# # Hands-on - Data Access with APIs

# %% [markdown]
# ## HugginfFace Dataset API

# %%
# !pip install -U datasets
# !pip install wget
# !pip install pdf2image
# !pip install -U wordcloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 10.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=60407c9afe033fb5934bddf44e19cddd7c46a6003423ad58d7a25f4f09de3506
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
# !pip install amseg
# !pip install pytesseract

# %%
# Let's import the library. We typically only need at most two methods:
from datasets import list_datasets, load_dataset
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import wget
from amseg.amharicNormalizer import AmharicNormalizer as normalizer
from wordcloud import WordCloud
from amseg.amharicSegmenter import AmharicSegmenter
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # List available datasets

# %%
# Currently available datasets
datasets = list_datasets()

print(f"🤩 Currently {len(datasets)} datasets are available on the hub:")
pprint(datasets[:100] + [f"{len(datasets) - 100} more..."], compact=True)
# Out:
# <ipython-input-8-2cd671b4f77b>:2: FutureWarning: list_datasets is deprecated and will be removed in the next major version of datasets. Use 'huggingface_hub.list_datasets' instead.
#   datasets = list_datasets()
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 🤩 Currently 143301 datasets are available on the hub:
# ['acronym_identification', 'ade_corpus_v2', 'UCLNLP/adversarial_qa', 'aeslc',
#  'afrikaans_ner_corpus', 'ag_news', 'allenai/ai2_arc', 'air_dialogue',
# ...

# %%
mylist = []
for dataset in datasets:
    if 'Amharic'.lower() in dataset.lower():
        mylist.append(dataset)

# %%
mylist
# Out:
# ['israel/Amharic-News-Text-classification-Dataset',
#  'surafelkindu/Amharic_corpus',
#  'Ephrem/Amharic_ASR_Dataset',
#  'Samuael/ALFFAAmharic',
#  'uhhlt/amharichatespeechranlp',
#  'Henok/amharic-qa',
#  'Am4nu3l/amharic-language-voices',
#  'danielmekuriaw/Amharic-Text-Summarization-Benchmark-Dataset',
#  'israel/AmharicSpellCheck',
#  'israel/AmharicStoryGeneration',
#  'israel/AmharicQA',
#  'israel/AmharicZefen',
#  'KerVerse/Amharic_Stories',
#  'BiniyamAjaw/amharic-corpus',
#  'Ermiasa/amharicSpeech',
#  'rcade/amharic_words',
#  'dagim/amharic-qa',
#  'BiniyamAjaw/amharic_dataset_v1',
#  'BiniyamAjaw/amharic_dataset_v2',
#  'Tvsybkzkmapab/Amharic_ad_generation',
#  'OCR-Ethiopic/row_col_amharic',
#  'iocuydi/amharic-dolly-15k',
#  'iocuydi/amharic-OASST1-pruned',
#  'iocuydi/amharic-visual-instruction-tuning',
#  'iocuydi/amharic-alpaca',
#  'iocuydi/amharic-redpajama-synthetic',
#  'mHossain/Amharic_sum_final',
#  'EthioNLP/Amharic_LLAMA',
#  'EthioNLP/Amharic_LLAMA_MT',
# ...

# %%
# Downloading and loading a dataset
dataset = load_dataset('uhhlt/amharichatespeechranlp')
# Out:
# ...
# Generating dev split:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'text'],
#         num_rows: 12000
#     })
#     test: Dataset({
#         features: ['label', 'text'],
#         num_rows: 1501
#     })
#     dev: Dataset({
#         features: ['label', 'text'],
#         num_rows: 1500
#     })
# })

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 12000
# })

# %% [markdown]
# ## Convert to pandas

# %%
pd.set_option('display.max_colwidth', None) # display full text
df = pd.DataFrame.from_dict(dataset["train"])
df
# Out:
#            label  \
# 0      offensive
# 1         normal
# 2         normal
# 3         normal
# 4      offensive
# ...          ...
# 11995       hate
# 11996     normal
# 11997       hate
# 11998     normal
# 11999       hate
#
#                                                                                                                  text
# 0                                            @USER እዚያው እየተላላክ ዳቦህን ብላ። ምነው ሠፊ ነው ካልክ ሀገር ቤት ሂደህ የወትሮ ሥራህን አልሰራህ ታዲያ?
# 1                                                                        የበረራ እቅድ አላ ልዟይተ ልካአ ህድቅእየ ምን እያደረገልኝ ነው ውወተ
# 2                @USER @USER የምን ጠላ ጠላ ፥ የምን ጠጅ ጠጅ ጠላትን መጋበዝ ፥ ቡን አርጎ ነው እንጅ ! ወደ ርዕሰ ከተማዋ ሲዘልቁ ቡና እንጋብዛለን ለማለት ነው :-
# 3                                                                      @USER @USER @USER @USER ይመስገን ዞላ ምርመራው ላይ አለበት
# 4                                                      @USER @USER ተራ ያልተማረ ደደብ ፋሽስት ያንተው ቅል ራስ መለስ መሆኑን አለማወቅህ ያሳዝናል
# ...

# %%
df['label'].hist()

# add labels and title
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.title('Distribution of Labels')
# Out:
# Text(0.5, 1.0, 'Distribution of Labels')

# %% [markdown]
# # Wordcloud

# %%
wget.download('https://github.com/uhh-lt/ethiopicmodels/raw/master/am/normalization/amstopwords.txt')
# Out:
# 'amstopwords.txt'

# %%
stopwords  = []
with open("./amstopwords.txt", "r") as st:
    for line in st:
        stopwords.append(normalizer.normalize(line.strip()))
len(stopwords)
# Out:
# 308

# %%
import re
def removeURL(data):
    data = ' '.join(re.sub("(@[A-Za-z0-9_]+)", "@USER", data).split())# USEE
    data =  ' '.join(re.sub('(((ftp|http|https):\/\/)|www)(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', 'URL', data).split()) # URL
    return data

# %%
wget.download('http://ltdata1.informatik.uni-hamburg.de/amharic/Tera-Regular.ttf')
# Out:
# 'Tera-Regular.ttf'

# %%
# Create a WordCloud object
wordcloud = WordCloud(background_color="white",\
                      contour_width=3, stopwords = set(stopwords), \
                      width=1000, height=600,contour_color='steelblue',\
                      font_path="./Tera-Regular.ttf")

# %%
# Generate a word cloud
text = normalizer.normalize(removeURL(','.join(list(df['text'].values))).replace("ER","").replace("R",""))

# %%
text
# Out:
# '@US እዚያው እየተላላክ ዳቦህን ብላ። ምነው ሰፊ ነው ካልክ ሃገር ቤት ሂደህ የወትሮ ስራህን አልሰራህ ታድያ?,የበረራ እቅድ አላ ልዟይተ ልካአ ህድቅእየ ምን እያደረገልኝ ነው ውወተ,@US @US የምን ጠላ ጠላ ፥ የምን ጠጅ ጠጅ ጠላትን መጋበዝ ፥ ቡን አርጎ ነው እንጅ ! ወደ ርእሰ ከተማዋ ሲዘልቁ ቡና እንጋብዛለን ለማለት ነው :-,@US @US @US @US ይመስገን ዞላ ምርመራው ላይ አለበት,@US @US ተራ ያልተማረ ደደብ ፋሽስት ያንተው ቅል ራስ መለስ መሆኑን አለማወቅህ ያሳዝናል,@US አደፓን አትመን፤የሴራው አካል ናቸው። ትኩረታቸው አሁንም ህወሃት እና የትግራይ ህዝብ ነው። ጉዳዩን አዙረው አክረው ወደ ህወሃት የማነጣጠር ነው፡ የወሬው ቅኝት።,በማንነታቸው ብቻ ተለይተው የተጨፈጨፉ አማሮችን ሽፋን ላለመስጠት አንድ ሴት ነብስ አተረፈች ብሎ ያዙኝ ልቀቁኝ በጣም ያሳዝናል አቁሙ ታስጠላላቹ ማፈሪያወች ?? ሞት ለህወሃት ሞት,@US @US @US ኢትዮጵያን የሚለው እርሶን ከጨመረ ቀጣይ መከራከር አያስፈልገንም ?? ስለራስወ ብቻ መስክረዋል አይጨምርም ካሉ,4/ አብረው ያለሙም፣ ያጠፉም መሪወቻችን ህዝብን በሁለት ጎራ አቧድነው እንድህ እንደ አረመኔ አገር ሲያባሉት ትክክል አይደለም ብለን የተሟገትን ማንኛችን ነን? ከጥፋት ያላበረ፣ በስ,@US እነዚህን ጸረ አማራና ኢትዮጵያ ሰወች በብዛት እጩ ታደርግ እና አንድ እና ሁለት መልካም ሰወች ማጣፈጫ ጣል ታደርጋላችሁ።ማንንም አትሸውድም ግደሉን ጨርሱን ኢትዮጵያ,@US በባለፈው ስብሰባችሁ በትግራይ ምስክኖች ስም ከተሰበሰበው ስንቱን ልትልኩ አሰባችሁ?ነው ወይስ ሁሉንም ልትቀረጥፉት ነው? ለነገሩ ጁንታው የለ ማን ያስለመድከው,@US @US እረ እንች ሴትዮ ዝም ብለሽ የማንም ወያኔ የሚበጠረቀውን እንደ ውነት ይዘሽ አት
# ...

# %%
wordcloud.generate(text)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x600>

# %%
wget.download("https://t4.ftcdn.net/jpg/02/51/62/37/360_F_251623750_3HQ3Et1LOvNGbhXHSWd8QNc0cYVE2rlv.jpg")
mask = np.array(Image.open("360_F_251623750_3HQ3Et1LOvNGbhXHSWd8QNc0cYVE2rlv.jpg"))

# %%
wordcloud = WordCloud(background_color="black",\
                      contour_width=3, stopwords = set(stopwords), \
                      width=2000, height=1600,contour_color='steelblue',\
                      font_path="./Tera-Regular.ttf", mask=mask)

# %%
wordcloud.generate(text)
plt.imshow(wordcloud, interpolation = "None")
# Off the x and y axis
plt.axis('off')

# Now show the output cloud
plt.show()

# %% [markdown]
# ## Amahric QA datasets

# %%
qa_dataset = load_dataset('israel/AmharicQA')
qa_dataset
# Out:
# ...
# Generating test split:   0%|          | 0/299 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['context', 'question', 'answers'],
#         num_rows: 1723
#     })
#     validation: Dataset({
#         features: ['context', 'question', 'answers'],
#         num_rows: 595
#     })
#     test: Dataset({
#         features: ['context', 'question', 'answers'],
#         num_rows: 299
#     })
# })

# %%
df = pd.DataFrame.from_dict(qa_dataset["train"])
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ## Machine translation

# %%
mt_dataset = load_dataset('EthioNLP/Amharic_LLAMA_MT')
mt_dataset
# Out:
# ...
# Generating test split:   0%|          | 0/2024 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output', 'prompt_header', 'datasource'],
#         num_rows: 200000
#     })
#     validation: Dataset({
#         features: ['instruction', 'input', 'output', 'prompt_header', 'datasource'],
#         num_rows: 1994
#     })
#     test: Dataset({
#         features: ['instruction', 'input', 'output', 'prompt_header', 'datasource'],
#         num_rows: 2024
#     })
# })

# %%
df = pd.DataFrame.from_dict(mt_dataset["train"])
df
# Out:
#                                          instruction  \
# 0          ለተሰጠው አማርኛ  አረፍተ ነገር ተቀራራቢ    አረፍተ ነገር ፃፍ
# 1          ለተሰጠው አማርኛ  አረፍተ ነገር ተቀራራቢ    አረፍተ ነገር ፃፍ
# 2                                 ተቅራራቢ  English  ፃፍ
# 3              የተሰጠውን የአማርኛ አረፍተ ነገር ወደ English ተርጉም
# 4                                 ተቅራራቢ  English  ፃፍ
# ...                                              ...
# 199995                               ተቅራራቢ  አማርኛ  ፃፍ
# 199996  ይህ ጽሁፍ በEnglish ቋንቋ ነው የተጻፈ ወደ አማርኛ ቋንቋ ተርጉም
# 199997       ይህንን የEnglish ቋንቋ ጽሑፍ በ አማርኛ ምን ማለት ነው?
# 199998  ለተሰጠው English  አረፍተ ነገር ተቀራራቢ    አረፍተ ነገር ፃፍ
# 199999  ይህ ጽሁፍ በEnglish ቋንቋ ነው የተጻፈ ወደ አማርኛ ቋንቋ ተርጉም
#
#                                                                                                                                                                                                     input  \
# ...

# %% [markdown]
# # Image data

# %%
image_dataset = load_dataset("cats_vs_dogs", split="train")
image_dataset[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for cats_vs_dogs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/cats_vs_dogs
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/23410 [00:00<?, ? examples/s]
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>,
#  'labels': 0}

# %%
image_dataset[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
image_dataset[11]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=461x320>

# %% [markdown]
# # Youtube data using API

# %% [markdown]
# ##  Setting Up YouTube API in Python
# - Get API Key
#   - Sign up for Google account.
#   - Go to Google Cloud Platform, create a new project.
#   - Enable YouTube Data API v3 and generate API keys.
# - Install Google API Client Library
#   - Use pip or Anaconda for installation.
# - Understand API Quota
#   - Daily limit of 10,000 units.
#   - Tips to maximize quota with multiple projects.

# %% [markdown]
# ## Making Queries with YouTube API

# %% [markdown]
# ## Stepes
# - Got to [Google cloud](https://console.cloud.google.com/)
# - create new project
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*k86eiqdHf9HhhxWKKnO7Sg.png)

# %% [markdown]
# ## Enable API
# - Once the project is created, navigate to Dashboard, select the project and `Explore and enable APIs`
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*KzdLen4agoUi33_H0MutcA.png)

# %% [markdown]
# # Click on + `ENABLE APIS AND SERVICES` at the top of the page
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*3HjyBix-P1gop_CPLYNpiQ.png)

# %% [markdown]
# ## Click `YouTube Data API v3` under YouTube
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*rzq6FpRfV0ujb_B6nUoGEA.png)

# %% [markdown]
# # Click Enable
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*FOTj3rvn0hGmHxgNz0x1Gw.png)

# %% [markdown]
# # Click on `CREATE CREDENTIALS` at the top right corner of the page
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*cLWdO9siuQE-3v0kPz-SAA.png)

# %% [markdown]
# ## Select `YouTube Data API v3 ` in the Select an API dropdown menu and check the `Public data` radio button
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*-3Kkw4rO6_Cl9eQf1wY0fA.png)

# %% [markdown]
# ## Copy the API Key
# ![](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*I-7gPXk6wPF_4jC7sJkNLQ.png)

# %%
# Install Google API client
# !pip install google-api-python-client

# %% [markdown]
# ## The quota allocation for everyone is of 10,000 units per day
#  - To maximize qouta, create 12 projects and you will have 120,000 credits per day
#  - Check the [References tab](https://developers.google.com/youtube/v3/docs) for more documentation

# %% [markdown]
# ## Summary
#  - `Resources`: YouTube's entities from which you can extract information.
#  -` Methods`: Functions which can be applied to the resources in order to extract their properties or modify them.
#  - `List methods`: This is the method of our interest since it can be used to retrieve collections of resources and then extract information about each one of them.

# %% [markdown]
#  - `Overview section`: Where the resource is explained. The most interesting part here is the Resource representation subsection. It will be useful since from there you will select the particular properties you want to retrieve from the resources you request.
#  - `list section`: Where the list method for each resource is explained.
#     - In the Parameters subsection you can see the required and optional parameters that can be used in order to customize the queries.
#     - In the Response subsection you can see the Response representation which includes the properties the query response has. It is important because you can also retrieve or ignore attributes of the responses.

# %% [markdown]
# ## Search video

# %%
DEVELOPER_KEY = 'AIzaSyB6O-4u7MDMerR6XaqXhHPxxpgW9vOiNUo'
# API client library
import googleapiclient.discovery
# API information
api_service_name = "youtube"
api_version = "v3"
# API client
youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)
# Request body indicating only the desired fields to be retrieved
# in 'fields' parameter

# %%
request = youtube.search().list(
        part="id,snippet",
        type='video',
        q="Addis Ababa Science and Technology University",
        videoDuration='short',
        videoDefinition='high',
        maxResults=1
)
# Request execution
response = request.execute()

# %%
pprint(response)
# Out:
# {'etag': 'CN4IVV7XLqKPTqZKMfgSM-XNzZ4',
#  'items': [{'etag': 'cNKv6uWJY_IHk6nefVmTKetsOgI',
#             'id': {'kind': 'youtube#video', 'videoId': 'fnS001q81E8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCIXyoPzOAWkk8b-z9kCYh-Q',
#                         'channelTitle': 'AASTU ECSF',
#                         'description': 'Connect With Us in all this social '
#                                        'media Platforms SOCIAL MEDIAS '
#                                        '=============================== - '
#                                        'FACEBOOK: ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2021-07-08T07:39:20Z',
#                         'publishedAt': '2021-07-08T07:39:20Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/fnS001q81E8/default.jpg',
# ...

# %%
pprint(response['items'])
# Out:
# [{'etag': 'cNKv6uWJY_IHk6nefVmTKetsOgI',
#   'id': {'kind': 'youtube#video', 'videoId': 'fnS001q81E8'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCIXyoPzOAWkk8b-z9kCYh-Q',
#               'channelTitle': 'AASTU ECSF',
#               'description': 'Connect With Us in all this social media '
#                              'Platforms SOCIAL MEDIAS '
#                              '=============================== - FACEBOOK: ...',
#               'liveBroadcastContent': 'none',
#               'publishTime': '2021-07-08T07:39:20Z',
#               'publishedAt': '2021-07-08T07:39:20Z',
#               'thumbnails': {'default': {'height': 90,
#                                          'url': 'https://i.ytimg.com/vi/fnS001q81E8/default.jpg',
#                                          'width': 120},
#                              'high': {'height': 360,
#                                       'url': 'https://i.ytimg.com/vi/fnS001q81E8/hqdefault.jpg',
# ...

# %% [markdown]
# ## Retrieve selected values

# %%
request = youtube.search().list(
        part="id,snippet",
        type='video',
        q="ኢትዮ ፎረም",
        videoDuration='short',
        videoDefinition='high',
        maxResults=1,
        fields="items(id(videoId),snippet(publishedAt,channelId,channelTitle,title,description))"
)
# Query execution
response = request.execute()
pprint(response)
# Out:
# {'items': [{'id': {'videoId': 'ds6tog7ujUo'},
#             'snippet': {'channelId': 'UCCsiR2EX0BwYE3gbwcWoDCw',
#                         'channelTitle': 'ETHIO FORUM ኢትዮ ፎረም',
#                         'description': 'ኢትዮ ፎረም፣በኢትዮጵያ የፖለቲካ፣የኢኮኖሚና የዲፕሎማሲ '
#                                        'ጉዳዮች ላይ የሚያተኩር የቴሌቪዥንና የዩቱዩብ ...',
#                         'publishedAt': '2023-02-13T05:31:07Z',
#                         'title': '🚨 ሰበር ዜና | ኢትዮ ፎረም ተመለሰ ፣ የ ብልፅግና እና ሻእብያ '
#                                  'ምስጥራዊ መረጃ | Ethio forum ኢትዮ ፎረም'}}]}

# %% [markdown]
# ## `nextPageToken` value to keep retrieving data concurrently without duplicated items

# %%
request = youtube.search().list(
        part="id,snippet",
        type='video',
        q="ኢትዮ ፎረም",
        videoDuration='short',
        videoDefinition='high',
        maxResults=1,
        fields="nextPageToken,items(id(videoId),snippet(publishedAt,channelId,channelTitle,title,description))"
)
response = request.execute()

# %%
pprint(response)
# Out:
# {'items': [{'id': {'videoId': 'ds6tog7ujUo'},
#             'snippet': {'channelId': 'UCCsiR2EX0BwYE3gbwcWoDCw',
#                         'channelTitle': 'ETHIO FORUM ኢትዮ ፎረም',
#                         'description': 'ኢትዮ ፎረም፣በኢትዮጵያ የፖለቲካ፣የኢኮኖሚና የዲፕሎማሲ '
#                                        'ጉዳዮች ላይ የሚያተኩር የቴሌቪዥንና የዩቱዩብ ...',
#                         'publishedAt': '2023-02-13T05:31:07Z',
#                         'title': '🚨 ሰበር ዜና | ኢትዮ ፎረም ተመለሰ ፣ የ ብልፅግና እና ሻእብያ '
#                                  'ምስጥራዊ መረጃ | Ethio forum ኢትዮ ፎረም'}}],
#  'nextPageToken': 'CAEQAA'}

# %%
request = youtube.search().list(
        part="id,snippet",
        type='video',
        q="ኢትዮ ፎረም",
        videoDuration='short',
        videoDefinition='high',
        maxResults=1,
        fields="nextPageToken,items(id(videoId),snippet(publishedAt,channelId,channelTitle,title,description))"
)
response = request.execute()
# Getting next token from the first query

# %%
nextToken = response['nextPageToken']

# %%
# Second query
request2 = youtube.search().list(
        part="id,snippet",
        type='video',
        q="ኢትዮ ፎረም",
        videoDuration='short',
        videoDefinition='high',
        maxResults=1,
        fields="nextPageToken,items(id(videoId),snippet(publishedAt,channelId,channelTitle,title,description))",
        pageToken=nextToken
)
response2 = request2.execute()

# %%
print("\n=====\nRESPONSE 1\n======\n")
pprint(response)
print("\n=====\nRESPONSE 2\n======\n")
pprint(response2)
# Out:
# =====
# RESPONSE 1
# ...
#
# {'items': [{'id': {'videoId': 'ds6tog7ujUo'},
#             'snippet': {'channelId': 'UCCsiR2EX0BwYE3gbwcWoDCw',
#                         'channelTitle': 'ETHIO FORUM ኢትዮ ፎረም',
#                         'description': 'ኢትዮ ፎረም፣በኢትዮጵያ የፖለቲካ፣የኢኮኖሚና የዲፕሎማሲ '
#                                        'ጉዳዮች ላይ የሚያተኩር የቴሌቪዥንና የዩቱዩብ ...',
#                         'publishedAt': '2023-02-13T05:31:07Z',
#                         'title': '🚨 ሰበር ዜና | ኢትዮ ፎረም ተመለሰ ፣ የ ብልፅግና እና ሻእብያ '
#                                  'ምስጥራዊ መረጃ | Ethio forum ኢትዮ ፎረም'}}],
#  'nextPageToken': 'CAEQAA'}
#
# =====
# RESPONSE 2
# ...
#
# {'items': [{'id': {'videoId': 'XF4H20nX97k'},
#             'snippet': {'channelId': 'UCXUFyN9Ys5tiIHgJFQKRJvA',
#                         'channelTitle': 'Ethio Forum ኢትዮ ፎረም',
#                         'description': 'የሴራ እርካብ የደም መንበር.',
#                         'publishedAt': '2024-03-13T19:13:06Z',
# ...

# %% [markdown]
# ### How to access to query responses data

# %%
print("RESPONSE 1")
print("Next page token:", response['nextPageToken'])
print("Video id:", response['items'][0]['id']['videoId'])
print("Publish date:", response['items'][0]['snippet']['publishedAt'])
print("Title:", response['items'][0]['snippet']['title'])

print("\nRESPONSE 2")
print("Next page token:", response2['nextPageToken'])
print("Video id:", response2['items'][0]['id']['videoId'])
print("Publish date:", response2['items'][0]['snippet']['publishedAt'])
print("Title:", response2['items'][0]['snippet']['title'])
# Out:
# RESPONSE 1
# Next page token: CAEQAA
# Video id: ds6tog7ujUo
# Publish date: 2023-02-13T05:31:07Z
# Title: 🚨 ሰበር ዜና | ኢትዮ ፎረም ተመለሰ ፣ የ ብልፅግና እና ሻእብያ ምስጥራዊ መረጃ | Ethio forum ኢትዮ ፎረም
#
# RESPONSE 2
# Next page token: CAIQAA
# Video id: XF4H20nX97k
# Publish date: 2024-03-13T19:13:06Z
# Title: የሴራ እርካብ የደም መንበር፤ በያየሰው ሽመልስ

# %% [markdown]
# ## Example, search and save in Pandas
# - About specific topics
# - Get the `publish date`, `title`, `number of views`, `likes`, `dislikes`, `comments` and `favorite count`.

# %%
# ሐኪም query
hakim_videos_ids = youtube.search().list(
    part="id",
    type='video',
    regionCode="ET",
    order="relevance",
    q="ሐኪም",
    maxResults=50,
    fields="items(id(videoId))"
).execute()
# ግብርና query
gibirina_videos_ids = youtube.search().list(
        part="id",
        type='video',
        regionCode="ET",
        order="relevance",
        q="ግብርና",
        maxResults=50,
        fields="items(id(videoId))"
).execute()

# %%
hakim_info = {
    'id':[],
    'duration':[],
    'views':[],
    'likes':[],
    'favorites':[],
    'comments':[]
}

# %%
gibirina_info = {
    'id':[],
    'duration':[],
    'views':[],
    'likes':[],
    'favorites':[],
    'comments':[]
}

# %%
for item in hakim_videos_ids['items']:
    # Getting the id
    vidId = item['id']['videoId']
    # Getting stats of the video
    r = youtube.videos().list(
        part="statistics,contentDetails",
        id=vidId,
        fields="items(statistics," + \
                     "contentDetails(duration))"
    ).execute()
    try:
        duration = r['items'][0]['contentDetails']['duration']
        views = r['items'][0]['statistics']['viewCount']
        likes = r['items'][0]['statistics']['likeCount']
        favorites = r['items'][0]['statistics']['favoriteCount']
        comments = r['items'][0]['statistics']['commentCount']

        hakim_info['id'].append(vidId)
        hakim_info['duration'].append(duration)
        hakim_info['views'].append(views)
        hakim_info['likes'].append(likes)
        hakim_info['favorites'].append(favorites)
        hakim_info['comments'].append(comments)
    except:
        pass

# %%
for item in gibirina_videos_ids['items']:
    vidId = item['id']['videoId']
    r = youtube.videos().list(
        part="statistics,contentDetails",
        id=vidId,
        fields="items(statistics," + \
                     "contentDetails(duration))"
    ).execute()
    try:
        duration = r['items'][0]['contentDetails']['duration']
        views = r['items'][0]['statistics']['viewCount']
        likes = r['items'][0]['statistics']['likeCount']
        favorites = r['items'][0]['statistics']['favoriteCount']
        comments = r['items'][0]['statistics']['commentCount']

        gibirina_info['id'].append(vidId)
        gibirina_info['duration'].append(duration)
        gibirina_info['views'].append(views)
        gibirina_info['likes'].append(likes)
        gibirina_info['favorites'].append(favorites)
        gibirina_info['comments'].append(comments)
    except:
        pass

# %%
hakim_df = pd.DataFrame(data=hakim_info)
hakim_df.to_csv("hakim.csv", index=False)

gibirna_df = pd.DataFrame(data=gibirina_info)
gibirna_df.to_csv("gibirna.csv", index=False)

# %%
hakim_df
# Out:
#              id    duration    views  likes favorites comments
# 0   QEQtgteyumo    PT56M21S   220400  11035         0     1638
# 1   JE5QyFCaRqc    PT45M12S   259909   3462         0      557
# 2   kSHiKVnrcCE    PT10M39S    35725    859         0       47
# 3   mHTIco1wCr8    PT14M28S    27277    704         0       92
# 4   yI1oWsltBgY     PT7M47S     6964    194         0        6
# 5   6JSFT2ALG7s    PT16M50S      553     13         0        0
# 6   OXc7axRqBFA     PT31M8S  1127156  33879         0     1828
# 7   Rzgukz6kOMA    PT28M14S   197016   3172         0      321
# 8   nsUxw2O5Ick       PT46S     1469     34         0        1
# 9   sRfQDmuTNCU     PT15M8S    70880   1200         0      161
# 10  xHTPj9fvmOs      PT6M8S     6719    121         0       28
# 11  SngwXCoh52Y    PT14M11S    90782   2959         0      417
# 12  GxY3cCdtjQM     PT10M1S   132475   1553         0      320
# 13  wYSbupWRWO4    PT18M24S     2655    105         0        7
# ...

# %%
gibirna_df
# Out:
#              id  duration   views  likes favorites comments
# 0   _d4SLF4ZCSw  PT12M50S  341007  12204         0     1804
# 1   NiBCndWie4Y   PT1M38S    1739    139         0       23
# 2   yjx1pa8Hg58   PT1M55S     162      4         0        0
# 3   8YNdskfiNf0     PT25S    2568    153         0       23
# 4   PA56WBOnDUY   PT2M40S    4951    163         0       10
# 5   bYPyjypNlgw   PT8M46S   26998    880         0       94
# 6   yaOU-n_aA4I    PT3M4S   10564    203         0       13
# 7   ipbaXgW6NkU    PT3M1S     609     14         0        0
# 8   GAaXyMN4gtg   PT4M40S     310      7         0        0
# 9   Wl7V_WVz4ow   PT3M38S    1780     45         0        2
# 10  7_k4b-e8xsw   PT3M15S     925     17         0        0
# 11  GRQojQ7GO48  PT25M50S   15730    504         0       39
# 12  4USgOf5rJyQ     PT41S     228      3         0        0
# 13  MH9KSKJ0F1Q  PT19M53S   89977   3720         0      534
# 14  SpUxlQtFuqQ  PT29M18S    5980    103         0        4
# ...

# %% [markdown]
# ## Getting the comments

# %%
import re
CLEANR = re.compile('<.*?>')
def cleanhtml(data):
    cleantext = re.sub(CLEANR, '', data)
    return cleantext

# %%
def get_getcomment(vidId, count):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=vidId,
        maxResults=count
    )
    response = request.execute()
    for item in response['items']:
        comments.append(item['snippet']['topLevelComment']['snippet']['textDisplay'])
    return comments

# %% [markdown]
# # <span style="color:red">Excercise</span>
# Complete the following code so that you can write the comment into pandas. The pandas will have `VideoID` and `comments` as a header.

# %%
comments = {
    'vidId': [],
    'comments':[]
}
for item in gibirina_videos_ids['items']:
    vidId = item['id']['videoId']
    try:
        for comment in get_getcomment(vidId, 100):
            ....
    except:
        pass

comments_df = ...
# Out:
#   File "<ipython-input-57-df067f0d3521>", line 9
#     ....
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # <span style="color:red">Mini-Project</span>
# - Choose a Youtube Channel (in Amharic) of you prefference, maybe a popular one and manually get one of the vedio ID.
# - Extract all the comments and save them into Pandas
# - Use the Amharic Sentiment analyzer and predict the sentiment for each of the comments
# - Plot a class distrubution bar chart showing the number of `positive`, `negative`, and `neutral` comments
#
# - HINT: To get the video id, open the YouTube Video and the id is the one after the `?v` String. For example:
#
# https://www.youtube.com/watch?v=jl33Se0lOiU, here the video ID is `jl33Se0lOiU`

# %% [markdown]
# ## `Hint`: Amharic Sentiment model

# %%
# !pip install wget
# !pip install flair

# %%
import wget
import flair
from flair.data import Sentence
am_sent_model = wget.download("http://ltdata1.informatik.uni-hamburg.de/amharic/taskmodels/sent/final-model.pt")

# create example sentence
sentence = Sentence('ስንት ምስኪን ነበር ያኔ:: አንዱ ሲኒየር ነን ካፌ ላድርጋችሁ ብሎን ስንት ምግብ አዘን አብሮ የበላውን ክፈሉ ብሎን ጠፍቷል')

# predict class and print
from flair.models import TextClassifier
classifier = TextClassifier.load(am_sent_model)
classifier.predict(sentence)
print(sentence.labels)

# %% [markdown]
# # Resources
# - [A Compendium of Data Sources for Data Science, Machine Learning, and Artificial Intelligence](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=4567555)
# - [YouTube API](https://medium.com/mcd-unison/youtube-data-api-v3-in-python-tutorial-with-examples-e829a25d2ebd)
